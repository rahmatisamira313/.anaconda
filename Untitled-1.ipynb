# %%
import numpy as np


data = np.array ([[1, 87, 0],
                 [2, 92, 0],
                 [3, 78, 0],
                 [4, 95, 0],
                 [5, 88, 0],
                 [6, 81, 1],
                 [7, 74, 1],
                 [8, 90, 1],
                 [9, 85,1],
                 [10,77, 1]])

filtered_data = data[data[:, -1] == 0]

print(filtered_data)

# %%
import numpy as np


data = np.array ([[1, 87, 0],
                 [2, 92, 0],
                 [3, 78, 0],
                 [4, 95, 0],
                 [5, 88, 0],
                 [6, 81, 1],
                 [7, 74, 1],
                 [8, 90, 1],
                 [9, 85,1],
                 [10,77, 1]])


# Filter rows where the last column equals 1
filtered_ones = data[data[:, -1] == 1]

print(filtered_ones)

# %%
import numpy as np


data = np.array ([[1, 87, 0],
                 [2, 92, 0],
                 [3, 78, 0],
                 [4, 95, 0],
                 [5, 88, 0],
                 [6, 81, 1],
                 [7, 74, 1],
                 [8, 90, 1],
                 [9, 85,1],
                 [10,77, 1]])


# Filter rows where the last column equals 1
filtered_ones = data[data[:, -1] == 1]

print(filtered_ones)
total_average1 = np.mean(filtered_data)
print(total_average1)

# %%
zeros = ([[ 1, 87,  0],
 [ 2, 92,  0],
 [ 3 ,78,  0],
 [ 4, 95,  0],
 [ 5, 88,  0]])

average = np.mean(zeros)
print(average)
